# %%
# Import the necessary functions and libraries
from kernel import kc_distance_wrapper
import tskit, msprime
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 from kernel import kc_distance_wrapper
#       3 import tskit, msprime
# ----> 5 ts1 = tskit.load("example_tree_sequence_1.trees")
#       6 ts2 = tskit.load("example_tree_sequence_2.trees")
#       7 dist = kc_distance_wrapper(ts1, ts2)  # This will internally use sample_lists=True
#
# File ~/code/ts-mcmc/myenv/lib/python3.13/site-packages/tskit/trees.py:3413, in load(file, skip_tables, skip_reference_sequence)
#    3390 def load(file, *, skip_tables=False, skip_reference_sequence=False):
#    3391     """
#    3392     Return a :class:`TreeSequence` instance loaded from the specified file object or
#    3393     path. The file must be in the
#    (...)
#    3411     :rtype: :class:`tskit.TreeSequence`
#    3412     """
# -> 3413     return TreeSequence.load(
# ...

# %%
# Out:
# Precon 'id':
#  [[1. 0.]
#  [0. 1.]]
# Precon '2.0':
#  [[0.5 0. ]
#  [0.  0.5]]
# Precon 'med':
#  [[1. 0.]
#  [0. 1.]]
# Precon 'sclmed':
#  [[1.09861229 0.        ]
#  [0.         1.09861229]]
# Precon 'smpcov':
#  [[4. 2.]
#  [2. 4.]]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 15
#      12     return np.array(results)
#      14 # Create Stein kernel function using make_imq
# ---> 15 kernel_func = make_imq(smp, scr, pre="id")  # should use identity preconditioner
#      17 # Take two points from smp and their gradients to test
#      18 pt1, pt2 = smp[0], smp[1]
#
# TypeError: make_imq() got an unexpected keyword argument 'pre'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 S_small = -X_small
#       5 # Create Stein kernel function for this sample
# ----> 6 kern_small = make_imq(X_small, S_small, pre="id")
#       7 K = np.round(kmat(X_small, S_small, kern_small), 4)
#       8 print("Stein kernel matrix K:\n", K)
#
# TypeError: make_imq() got an unexpected keyword argument 'pre'
